# %%
import selenium
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select
import time
import pandas as pd
from bs4 import BeautifulSoup
from tqdm import tqdm
import os
import re
folderpath=r"C:\Users\Zoe\Desktop\maz-datenjournalismus\Daten_BR_Handelsreg"

# %% [markdown]
# # Abgleichen von Adress-Frame und Scrape-Frame
# Sind alle Adressen runtergezogen

# %%
df_adan=pd.read_csv(folderpath+"/BRFrames/StadtZug_extrahiert_unbereinigt") #das gescrapte Frame
df_st_zug=pd.read_csv(folderpath+"/BRFrames/adresse_Zug") # die ursprünglichen Adressen

# %%
df_abgleich=pd.merge(df_adan, df_st_zug, on="Adresse", how="outer")

# %%
df_abgleich.drop_duplicates("Adresse", inplace=True)

# %%
df_abgleich
# Out:
#       Unnamed: 0_x              Seite  Anzahl                    Adresse  \
# 0              0.0     frontpage0.htm     NaN       Aabachstrasse 1, Zug
# 1              1.0     frontpage1.htm     5.0      Aabachstrasse 10, Zug
# 2              2.0    frontpage10.htm     NaN       Aabachstrasse 2, Zug
# 3              3.0   frontpage100.htm     NaN  Alte Baarerstrasse 4, Zug
# 4              4.0  frontpage1000.htm     NaN   Chamerstrasse 180.2, Zug
# ...            ...                ...     ...                        ...
# 5645           NaN                NaN     NaN            Rüschenhof, Zug
# 5646           NaN                NaN     NaN              Schönegg, Zug
# 5647           NaN                NaN     NaN          Göblistrasse, Zug
# 5648           NaN                NaN     NaN      Rüsli, Oberwil b. Zug
# 5649           NaN                NaN     NaN              Lüssiweg, Zug
#
#       Unnamed: 0_y         EGID  EDID GDEKT   GDENR GDENAME  \
# ...

# %%
# Alle Adressen filtern, die NAN-Werte haben - also nicht funktionierten
# https://stackoverflow.com/questions/22551403/python-pandas-filtering-out-nan-from-a-data-selection-of-a-column-of-strings
df_fehlende=df_abgleich[df_abgleich["Seite"].notnull()==False]

# %%
df_fehlende.to_csv(folderpath+"/BRFrames/Stadt_Zug_fehlende_adressem")
